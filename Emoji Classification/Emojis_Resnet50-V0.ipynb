# %% [markdown]
# <a href="https://colab.research.google.com/github/smara97/Machine-Learning-projects/blob/master/Emojis_Resnet50-V0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install emoji
# Out:
# Collecting emoji
#   Downloading https://files.pythonhosted.org/packages/1b/d7/2746b4dd67375ce253e777ba54869545d24d2b0249ebcf83735c99df68d5/emoji-0.5.3.tar.gz (43kB)
#      |████████████████████████████████| 51kB 3.4MB/s
# Building wheels for collected packages: emoji
#   Building wheel for emoji (setup.py) ... done
#   Created wheel for emoji: filename=emoji-0.5.3-cp36-none-any.whl size=42175 sha256=2e226e08e9d03a6e5f97d751a1fb544709ce37fbc08c405f1d2ca74094bb4e25
#   Stored in directory: /root/.cache/pip/wheels/86/09/26/f944015841423cd516e8a97f30e29be59e53461aea8b7d3458
# Successfully built emoji
# Installing collected packages: emoji
# Successfully installed emoji-0.5.3

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import files,drive
import torch,cv2
from torchvision import models,datasets,transforms
from PIL import Image
import torch.nn.functional as F
from torch import nn,optim
from torch.autograd import Variable
from sklearn.model_selection import train_test_split
from torch.optim import lr_scheduler
import time,emoji
from torch.utils.data import Dataset
# %matplotlib inline

# %%
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
p='/content/drive/"My Drive"/"Emoji dataset"'
# !ls {p}
# Out:
# 'Call me'      'Middle finger'	'Sign of horrs'  'Vulcan sulate'
# 'Forced hand'  'Raised hand'	'Victory hand'

# %%
image_datasets = datasets.ImageFolder(root= "/content/drive/My Drive/Emoji dataset/")

# %%
class experimental_dataset(Dataset):

    def __init__(self, data,transform):
        self.data = data
        self.transform = transform

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()
        item = self.data[idx][0]
        item = self.transform(item)
        return [item,self.data[idx][1]]

# %%
train_transforms = transforms.Compose([transforms.Resize(size=200),
        transforms.RandomRotation(degrees=15),
        transforms.RandomHorizontalFlip(),
        transforms.CenterCrop(size=224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225])
    ])

test_transforms = transforms.Compose([transforms.Resize(256),
                                      transforms.CenterCrop(224),
                                      transforms.ToTensor(),
                                      transforms.Normalize((0.485,0.456,0.406),(0.299,0.224,0.225))])

# %%
train_size = int(0.85 * len(image_datasets))
valid_size=int(0.10*len(image_datasets))
test_size = len(image_datasets) - train_size-valid_size

train_dataset,valid_dataset, test_dataset = torch.utils.data.random_split(image_datasets, [train_size,valid_size, test_size])

# %%
print("Number of Examples Of  Trainning Dataset ",len(train_dataset))
print("Number of Examples Of  Validation Dataset ",len(valid_dataset))
print("Number of Examples Of  Testing Dataset ",len(test_dataset))
# Out:
# Number of Examples Of  Trainning Dataset  942
# Number of Examples Of  Validation Dataset  110
# Number of Examples Of  Testing Dataset  57

# %%
train_dataset=experimental_dataset(train_dataset,train_transforms)
valid_dataset=experimental_dataset(valid_dataset,test_transforms)
test_dataset=experimental_dataset(test_dataset,test_transforms)

# %%
trainloader = torch.utils.data.DataLoader(train_dataset, batch_size=32, shuffle=True)
validloader=torch.utils.data.DataLoader(valid_dataset,batch_size=32,shuffle=True)
testloader=torch.utils.data.DataLoader(test_dataset,batch_size=32,shuffle=True)

# %%
dataiter = iter(trainloader)
images,labels= next(dataiter)

# %%
def im_convert(tensor):
    image=tensor.numpy().squeeze()
    image=image.transpose(1,2,0)
    image=image*np.array((0.229,0.224,0.225))+np.array((0.485,0.456,0.406))
    image=image.clip(0,1)
    
    return image

# %%
cat={0:"Call Me",1:"Forced Hand",2:"Middle Finger",3:"Raised Hand",4:"Sign of Horns",5:"Victory Hand",6:"Vulcan Sulate"}
Emo={0:":call_me_hand:",1:":raised_fist:",2:":middle_finger:",3:":raised_hand:",4:":sign_of_the_horns:",5:":victory_hand:",6:":vulcan_salute:"}

# %%
fig = plt.figure(figsize=(15, 4))
for idx in np.arange(10):
    ax = fig.add_subplot(2, 10/2, idx+1, xticks=[], yticks=[])
    plt.imshow(im_convert(images[idx]))
    plt.title(cat[labels[idx].item()]+' '+emoji.emojize(Emo[labels[idx].item()]))

# %%
model=models.resnet50(pretrained=True)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.cache/torch/checkpoints/resnet50-19c8e357.pth
# 100%|██████████| 102502400/102502400 [00:01<00:00, 65867100.94it/s]

# %%
for param in model.parameters():
    param.requires_grad = False
    
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
fc_inputs = model.fc.in_features
 
model.fc = nn.Sequential(
    nn.Linear(fc_inputs, 256),
    nn.ReLU(),
    nn.Dropout(0.5),
    nn.Linear(256, 7), 
    nn.LogSoftmax(dim=1) # For using NLLLoss()
)

# %%
criterion = nn.NLLLoss()

# Only train the classifier parameters, feature parameters are frozen
optimizer = optim.Adam(model.parameters(), lr=0.001)

model.to(device);

# %%
epochs=30
valid_loss_min = np.Inf
validlosses,trainlosses=[],[]
validacc,trainacc=[],[]

for epoch in range(epochs):
  print("Epoch: {}/{} ........".format(epoch+1, epochs))
  
  start = time.time()
 
  
  steps=0
  running_loss=0.0
  accuracy_train=0.0
  
  steps2=0
  valid_loss = 0
  accuracy_valid = 0
    
  model.train()
  
  
  for inputs, labels in trainloader:
    
    steps += 1
    # Move input and label tensors to the default device
    inputs, labels = inputs.to(device), labels.to(device)
        
    optimizer.zero_grad()
        
    logps = model(inputs)
    loss = criterion(logps, labels)
    loss.backward()
    optimizer.step()

    running_loss += loss.item()*inputs.size(0)
    
    ret, predictions = torch.max(logps.data, 1)
    correct_counts = predictions.eq(labels.data.view_as(predictions))
    # Convert correct_counts to float and then compute the mean
    acc = torch.mean(correct_counts.type(torch.FloatTensor))
         
    # Compute total accuracy in the whole batch and add to train_acc
    accuracy_train += acc.item() * inputs.size(0)
    print("Training Batch number: {:03d}, Training: Loss: {:.4f}, Accuracy: {:.4f}".format(steps, loss.item(), acc.item()))
    
  else:
   
    with torch.no_grad():
      model.eval()
      for inputs, labels in validloader:
        steps2+=1
        inputs, labels = inputs.to(device), labels.to(device)
        logps = model.forward(inputs)
        loss = criterion(logps, labels)
                    
        valid_loss += loss.item()
        # Calculate validation accuracy
        ret, predictions = torch.max(logps.data, 1)
        correct_counts = predictions.eq(labels.data.view_as(predictions))
 
        # Convert correct_counts to float and then compute the mean
        acc = torch.mean(correct_counts.type(torch.FloatTensor))
        
 
        # Compute total accuracy in the whole batch and add to valid_acc
        accuracy_valid += acc.item() * inputs.size(0)
        print("Validation Batch number: {:03d}, Validation: Loss: {:.4f}, Accuracy: {:.4f}".format(steps2, loss.item(), acc.item()))
    
    
  # Find average training loss and training accuracy
  avg_train_loss = running_loss/train_size 
  avg_train_acc = accuracy_train/float(train_size)
 
  # Find average training loss and training accuracy
  avg_valid_loss = valid_loss/valid_size 
  avg_valid_acc = accuracy_valid/float(valid_size)


  trainacc.append(avg_train_acc)
  validacc.append(avg_valid_acc)
  trainlosses.append(avg_train_loss)
  validlosses.append(avg_valid_loss)
  stop = time.time()

  end = time.time()
 
  print("Epoch : {:03d}, Training: Loss: {:.4f}, Accuracy: {:.4f}%, \n\t\tValidation : Loss : {:.4f}, Accuracy: {:.4f}%, Time: {:.4f}s".format(epoch+1, avg_train_loss, avg_train_acc*100, avg_valid_loss, avg_valid_acc*100, end-start))
    
    
  if avg_valid_loss <= valid_loss_min:
      
      print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
# Validation loss decreased (0.017221 --> 0.017190).  Saving model ...
# Epoch: 27/30 ........
# Training Batch number: 001, Training: Loss: 0.3183, Accuracy: 0.8750
# Training Batch number: 002, Training: Loss: 0.6781, Accuracy: 0.7812
# Training Batch number: 003, Training: Loss: 0.3999, Accuracy: 0.8750
# Training Batch number: 004, Training: Loss: 0.1036, Accuracy: 1.0000
# Training Batch number: 005, Training: Loss: 0.3415, Accuracy: 0.9062
# Training Batch number: 006, Training: Loss: 0.3795, Accuracy: 0.8438
# Training Batch number: 007, Training: Loss: 0.3943, Accuracy: 0.8438
# Training Batch number: 008, Training: Loss: 0.4008, Accuracy: 0.9062
# Training Batch number: 009, Training: Loss: 0.6408, Accuracy: 0.7188
# Training Batch number: 010, Training: Loss: 0.7058, Accuracy: 0.6875
# Training Batch number: 011, Training: Loss: 0.3930, Accuracy: 0.8438
# Training Batch number: 012, Training: Loss: 0.3316, Accuracy: 0.9062
# Training Batch number: 013, Training: Loss: 0.6247, Accuracy: 0.7500
# Training Batch number: 014, Training: Loss: 0.2083, Accuracy: 0.9688
# Training Batch number: 015, Training: Loss: 0.4304, Accuracy: 0.8750
# Training Batch number: 016, Training: Loss: 0.4445, Accuracy: 0.8750
# Training Batch number: 017, Training: Loss: 0.3949, Accuracy: 0.9062
# Training Batch number: 018, Training: Loss: 0.5815, Accuracy: 0.7500
# Training Batch number: 019, Training: Loss: 0.5544, Accuracy: 0.8125
# Training Batch number: 020, Training: Loss: 0.6008, Accuracy: 0.7188
# Training Batch number: 021, Training: Loss: 0.3144, Accuracy: 0.8750
# Training Batch number: 022, Training: Loss: 0.3383, Accuracy: 0.8125
# Training Batch number: 023, Training: Loss: 0.4118, Accuracy: 0.8125
# Training Batch number: 024, Training: Loss: 0.2113, Accuracy: 1.0000
# Training Batch number: 025, Training: Loss: 0.1975, Accuracy: 0.9688
# Training Batch number: 026, Training: Loss: 0.2103, Accuracy: 0.9375
# Training Batch number: 027, Training: Loss: 0.4125, Accuracy: 0.7812
# Training Batch number: 028, Training: Loss: 0.2695, Accuracy: 0.9062
# Training Batch number: 029, Training: Loss: 0.3897, Accuracy: 0.8750
# Training Batch number: 030, Training: Loss: 0.5349, Accuracy: 0.7857
# Validation Batch number: 001, Validation: Loss: 0.5557, Accuracy: 0.8125
# Validation Batch number: 002, Validation: Loss: 0.5518, Accuracy: 0.7812
# Validation Batch number: 003, Validation: Loss: 0.4587, Accuracy: 0.8125
# Validation Batch number: 004, Validation: Loss: 0.1809, Accuracy: 1.0000
# Epoch : 027, Training: Loss: 0.4048, Accuracy: 85.4565%,
# 		Validation : Loss : 0.0159, Accuracy: 82.7273%, Time: 485.6474s
# Validation loss decreased (0.017190 --> 0.015883).  Saving model ...
# Epoch: 28/30 ........
# Training Batch number: 001, Training: Loss: 0.2274, Accuracy: 0.9062
# Training Batch number: 002, Training: Loss: 0.2025, Accuracy: 0.9688
# Training Batch number: 003, Training: Loss: 0.2973, Accuracy: 0.9062
# Training Batch number: 004, Training: Loss: 0.3762, Accuracy: 0.8438
# Training Batch number: 005, Training: Loss: 0.5391, Accuracy: 0.7188
# Training Batch number: 006, Training: Loss: 0.3580, Accuracy: 0.8438
# Training Batch number: 007, Training: Loss: 0.2235, Accuracy: 0.8438
# Training Batch number: 008, Training: Loss: 0.4462, Accuracy: 0.8750
# Training Batch number: 009, Training: Loss: 0.6359, Accuracy: 0.8750
# Training Batch number: 010, Training: Loss: 0.4180, Accuracy: 0.8750
# Training Batch number: 011, Training: Loss: 0.2964, Accuracy: 0.9062
# Training Batch number: 012, Training: Loss: 0.2461, Accuracy: 0.9688
# Training Batch number: 013, Training: Loss: 0.2930, Accuracy: 0.9062
# Training Batch number: 014, Training: Loss: 0.4188, Accuracy: 0.8125
# Training Batch number: 015, Training: Loss: 0.4112, Accuracy: 0.8438
# Training Batch number: 016, Training: Loss: 0.1866, Accuracy: 0.9062
# Training Batch number: 017, Training: Loss: 0.5245, Accuracy: 0.8125
# Training Batch number: 018, Training: Loss: 0.2371, Accuracy: 0.9062
# Training Batch number: 019, Training: Loss: 0.2249, Accuracy: 0.9375
# Training Batch number: 020, Training: Loss: 0.2312, Accuracy: 0.9375
# Training Batch number: 021, Training: Loss: 0.1779, Accuracy: 0.9375
# Training Batch number: 022, Training: Loss: 0.7580, Accuracy: 0.7500
# Training Batch number: 023, Training: Loss: 0.4868, Accuracy: 0.7812
# Training Batch number: 024, Training: Loss: 0.5911, Accuracy: 0.7812
# Training Batch number: 025, Training: Loss: 0.3177, Accuracy: 0.9062
# Training Batch number: 026, Training: Loss: 0.3710, Accuracy: 0.9062
# Training Batch number: 027, Training: Loss: 0.1638, Accuracy: 0.9688
# Training Batch number: 028, Training: Loss: 0.3142, Accuracy: 0.9375
# Training Batch number: 029, Training: Loss: 0.2805, Accuracy: 0.8750
# Training Batch number: 030, Training: Loss: 1.1115, Accuracy: 0.5714
# Validation Batch number: 001, Validation: Loss: 0.4440, Accuracy: 0.7812
# Validation Batch number: 002, Validation: Loss: 0.6717, Accuracy: 0.7188
# Validation Batch number: 003, Validation: Loss: 0.4804, Accuracy: 0.8750
# Validation Batch number: 004, Validation: Loss: 0.8656, Accuracy: 0.5714
# Epoch : 028, Training: Loss: 0.3649, Accuracy: 87.2611%,
# 		Validation : Loss : 0.0224, Accuracy: 76.3636%, Time: 483.5938s
# Epoch: 29/30 ........
# Training Batch number: 001, Training: Loss: 0.3393, Accuracy: 0.9375
# Training Batch number: 002, Training: Loss: 0.2998, Accuracy: 0.9062
# Training Batch number: 003, Training: Loss: 0.2216, Accuracy: 0.9062
# Training Batch number: 004, Training: Loss: 0.3786, Accuracy: 0.9062
# Training Batch number: 005, Training: Loss: 0.2833, Accuracy: 0.8750
# Training Batch number: 006, Training: Loss: 0.2065, Accuracy: 0.9688
# Training Batch number: 007, Training: Loss: 0.5131, Accuracy: 0.8438
# Training Batch number: 008, Training: Loss: 0.3349, Accuracy: 0.8750
# Training Batch number: 009, Training: Loss: 0.4554, Accuracy: 0.8750
# Training Batch number: 010, Training: Loss: 0.3111, Accuracy: 0.9062
# Training Batch number: 011, Training: Loss: 0.5486, Accuracy: 0.7188
# Training Batch number: 012, Training: Loss: 0.1562, Accuracy: 1.0000
# Training Batch number: 013, Training: Loss: 0.1576, Accuracy: 0.9688
# Training Batch number: 014, Training: Loss: 0.3905, Accuracy: 0.7812
# Training Batch number: 015, Training: Loss: 0.2347, Accuracy: 0.9375
# Training Batch number: 016, Training: Loss: 0.4620, Accuracy: 0.7812
# Training Batch number: 017, Training: Loss: 0.3489, Accuracy: 0.8750
# Training Batch number: 018, Training: Loss: 0.5329, Accuracy: 0.8438
# Training Batch number: 019, Training: Loss: 0.2955, Accuracy: 0.9062
# Training Batch number: 020, Training: Loss: 0.1267, Accuracy: 0.9688
# Training Batch number: 021, Training: Loss: 0.5420, Accuracy: 0.7500
# Training Batch number: 022, Training: Loss: 0.4275, Accuracy: 0.8750
# Training Batch number: 023, Training: Loss: 0.5147, Accuracy: 0.8125
# Training Batch number: 024, Training: Loss: 0.3762, Accuracy: 0.8750
# Training Batch number: 025, Training: Loss: 0.4149, Accuracy: 0.7812
# Training Batch number: 026, Training: Loss: 0.5273, Accuracy: 0.7812
# Training Batch number: 027, Training: Loss: 0.4229, Accuracy: 0.8125
# Training Batch number: 028, Training: Loss: 0.2586, Accuracy: 0.8750
# Training Batch number: 029, Training: Loss: 0.4267, Accuracy: 0.8125
# Training Batch number: 030, Training: Loss: 0.8846, Accuracy: 0.7143
# Validation Batch number: 001, Validation: Loss: 0.2365, Accuracy: 0.9062
# Validation Batch number: 002, Validation: Loss: 0.2627, Accuracy: 0.9062
# Validation Batch number: 003, Validation: Loss: 0.6493, Accuracy: 0.7500
# Validation Batch number: 004, Validation: Loss: 0.7640, Accuracy: 0.6429
# Epoch : 029, Training: Loss: 0.3701, Accuracy: 86.5180%,
# 		Validation : Loss : 0.0174, Accuracy: 82.7273%, Time: 499.7394s
# Epoch: 30/30 ........
# Training Batch number: 001, Training: Loss: 0.2144, Accuracy: 0.9688
# Training Batch number: 002, Training: Loss: 0.4526, Accuracy: 0.8125
# Training Batch number: 003, Training: Loss: 0.3908, Accuracy: 0.8125
# Training Batch number: 004, Training: Loss: 0.4510, Accuracy: 0.8125
# Training Batch number: 005, Training: Loss: 0.4613, Accuracy: 0.8750
# Training Batch number: 006, Training: Loss: 0.3537, Accuracy: 0.9062
# Training Batch number: 007, Training: Loss: 0.5346, Accuracy: 0.8125
# Training Batch number: 008, Training: Loss: 0.3027, Accuracy: 0.9375
# Training Batch number: 009, Training: Loss: 0.2242, Accuracy: 0.9375
# Training Batch number: 010, Training: Loss: 0.4654, Accuracy: 0.7812
# Training Batch number: 011, Training: Loss: 0.3770, Accuracy: 0.9062
# Training Batch number: 012, Training: Loss: 0.3041, Accuracy: 0.9062
# Training Batch number: 013, Training: Loss: 0.2632, Accuracy: 0.9375
# Training Batch number: 014, Training: Loss: 0.3601, Accuracy: 0.9062
# Training Batch number: 015, Training: Loss: 0.4131, Accuracy: 0.8125
# Training Batch number: 016, Training: Loss: 0.2536, Accuracy: 0.8750
# Training Batch number: 017, Training: Loss: 0.3071, Accuracy: 0.9062
# Training Batch number: 018, Training: Loss: 0.5102, Accuracy: 0.8750
# Training Batch number: 019, Training: Loss: 0.7534, Accuracy: 0.6875
# Training Batch number: 020, Training: Loss: 0.1736, Accuracy: 0.9688
# Training Batch number: 021, Training: Loss: 0.3404, Accuracy: 0.9062
# Training Batch number: 022, Training: Loss: 0.3762, Accuracy: 0.8750
# Training Batch number: 023, Training: Loss: 0.4532, Accuracy: 0.7812
# Training Batch number: 024, Training: Loss: 0.3238, Accuracy: 0.9375
# Training Batch number: 025, Training: Loss: 0.5092, Accuracy: 0.8125
# Training Batch number: 026, Training: Loss: 0.4772, Accuracy: 0.8438
# Training Batch number: 027, Training: Loss: 0.2821, Accuracy: 0.8750
# Training Batch number: 028, Training: Loss: 0.3743, Accuracy: 0.9062
# Training Batch number: 029, Training: Loss: 0.3537, Accuracy: 0.8438
# Training Batch number: 030, Training: Loss: 0.1310, Accuracy: 1.0000
# Validation Batch number: 001, Validation: Loss: 0.5450, Accuracy: 0.8125
# Validation Batch number: 002, Validation: Loss: 0.4671, Accuracy: 0.7812
# Validation Batch number: 003, Validation: Loss: 0.5319, Accuracy: 0.8125
# Validation Batch number: 004, Validation: Loss: 0.3360, Accuracy: 0.7857
# Epoch : 030, Training: Loss: 0.3775, Accuracy: 87.1550%,
# 		Validation : Loss : 0.0171, Accuracy: 80.0000%, Time: 529.4239s

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 6))
ax1.plot(trainlosses,label='Training Loss')
ax1.plot(validlosses,label='Validation Loss')

ax1.legend(frameon=False)

ax2.plot(trainacc,label='Training Accuracy')
ax2.plot(validacc,label='Validation Accuracy')

ax2.legend(frameon=False)

# %%
model.load_state_dict(torch.load('model_emoji.pt'))
# Out:
# IncompatibleKeys(missing_keys=[], unexpected_keys=[])

# %%
train_on_GPU=True
# track test loss
test_loss = 0.0
class_correct = list(0. for i in range(7))
class_total = list(0. for i in range(7))

model.eval()
# iterate over test data
for data, target in testloader:
    # move tensors to GPU if CUDA is available
    data, target = data.cuda(), target.cuda()
    # forward pass: compute predicted outputs by passing inputs to the model
    output = model(data)
    # calculate the batch loss
    loss = criterion(output, target)
    # update test loss 
    test_loss += loss.item()*data.size(0)
    # convert output probabilities to predicted class
    _, pred = torch.max(output, 1)    
    # compare predictions to true label
    correct_tensor = pred.eq(target.data.view_as(pred))
    correct = np.squeeze(correct_tensor.numpy()) if not train_on_GPU else np.squeeze(correct_tensor.cpu().numpy())
    # calculate test accuracy for each object class
    
    for i in range(len(target)):
        label = target.data[i]
        class_correct[label] += correct[i].item()
        class_total[label] += 1

# average test loss
test_loss = test_loss/len(testloader.dataset)
print('Test Loss: {:.6f}\n'.format(test_loss))

for i in range(7):
    if class_total[i] > 0:
        print('Test Accuracy of %5s: %2d%% (%2d/%2d)' % (
            cat[i], 100 * class_correct[i] / class_total[i],
            np.sum(class_correct[i]), np.sum(class_total[i])))
    else:
        print('Test Accuracy of %5s: N/A (no training examples)' % (classes[i]))

print('\nTest Accuracy (Overall): %2d%% (%2d/%2d)' % (
    100. * np.sum(class_correct) / np.sum(class_total),
    np.sum(class_correct), np.sum(class_total)))
# Out:
# Test Loss: 0.325779
#
# Test Accuracy of Call Me: 100% ( 9/ 9)
# Test Accuracy of Forced Hand: 100% ( 7/ 7)
# Test Accuracy of Middle Finger: 83% ( 5/ 6)
# Test Accuracy of Raised Hand: 70% ( 7/10)
# Test Accuracy of Sign of Horns: 90% ( 9/10)
# Test Accuracy of Victory Hand: 100% ( 7/ 7)
# Test Accuracy of Vulcan Sulate: 87% ( 7/ 8)
#
# Test Accuracy (Overall): 89% (51/57)

# %%
img=Image.open("/content/drive/My Drive/Test/2019-08-30-221105.jpg")

# %%
img=test_transforms(img)

# %%
imgshow=im_convert(img)
plt.imshow(imgshow)

# %%
img=img.view(1, 3, 224, 224).cuda()
with torch.no_grad():
  
  model.eval()
  # Model outputs log probabilities
  out = model(img)
  ps = torch.exp(out)
  topk, topclass = ps.topk(1, dim=1)
  pri="Output class :  "+ cat[topclass.cpu().numpy()[0][0]]+' '+emoji.emojize(str(Emo[topclass.cpu().numpy()[0][0]]))
  
  print(pri)
plt.imshow(imgshow)
# Out:
# Output class :  Sign of Horns 🤘
